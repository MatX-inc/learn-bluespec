-- %% [markdown]
-- # IHaskell Smoketest

-- %%
1 + 1
-- Out:
-- 2

-- %%
greeting :: String -> String
greeting name = "Hello, " ++ name ++ "!"

greeting "Bluespec"
-- Out:
-- "Hello, Bluespec!"

-- %%
data Color = Red | Green | Blue deriving Show

map show [Red, Green, Blue]
-- Out:
-- ["Red","Green","Blue"]
